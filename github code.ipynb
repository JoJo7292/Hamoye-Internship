# %%
import pandas as pd
import numpy as np

# %%
fuel_df = pd.read_excel('fuel_dataF.xlsx')

# %%
fuel_df.head(15)
# Out:
#                  record_id  utility_id_ferc1  report_year  \
# 0    f1_fuel_1994_12_1_0_7                 1         1994
# 1   f1_fuel_1994_12_1_0_10                 1         1994
# 2    f1_fuel_1994_12_2_0_1                 2         1994
# 3    f1_fuel_1994_12_2_0_7                 2         1994
# 4   f1_fuel_1994_12_2_0_10                 2         1994
# 5   f1_fuel_1994_12_2_0_13                 2         1994
# 6    f1_fuel_1994_12_2_1_1                 2         1994
# 7   f1_fuel_1994_12_2_1_10                 2         1994
# 8   f1_fuel_1994_12_2_2_10                 2         1994
# 9    f1_fuel_1994_12_4_0_1                 4         1994
# 10   f1_fuel_1994_12_4_0_2                 4         1994
# 11   f1_fuel_1994_12_4_0_4                 4         1994
# 12   f1_fuel_1994_12_4_0_5                 4         1994
# 13   f1_fuel_1994_12_6_0_1                 6         1994
# 14   f1_fuel_1994_12_6_0_2                 6         1994
#
# ...

# %%
fuel_df.groupby('fuel_cost_per_unit_burned').first()
# Out:
#                                           record_id  utility_id_ferc1  \
# fuel_cost_per_unit_burned
# -276.080                    f1_fuel_2000_12_194_3_3               194
# -174.670                    f1_fuel_2000_12_194_3_6               194
# -123.310                   f1_fuel_2000_12_194_2_15               194
# -119.040                    f1_fuel_2003_12_281_1_4               281
# -85.760                     f1_fuel_1995_12_194_5_9               194
# -85.750                    f1_fuel_1995_12_194_5_12               194
# -70.884                      f1_fuel_2011_12_27_1_3                27
# -59.680                     f1_fuel_2002_12_281_1_4               281
# -57.490                    f1_fuel_1994_12_194_5_12               194
# -57.470                    f1_fuel_1994_12_194_5_15               194
# -57.450                     f1_fuel_1994_12_194_5_9               194
# -53.630                     f1_fuel_1995_12_194_4_9               194
# ...

# %%
fuel_df['fuel_cost_per_unit_burned'].describe()
# Out:
# count     29523.000000
# mean        208.649031
# std        2854.490090
# min        -276.080000
# 25%           5.207000
# 50%          26.000000
# 75%          47.113000
# max      139358.000000
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
fuel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
# record_id                       29523 non-null object
# utility_id_ferc1                29523 non-null int64
# report_year                     29523 non-null int64
# plant_name_ferc1                29523 non-null object
# fuel_type_code_pudl             29523 non-null object
# fuel_unit                       29523 non-null object
# fuel_qty_burned                 29523 non-null int64
# fuel_mmbtu_per_unit             29523 non-null float64
# fuel_cost_per_unit_burned       29523 non-null float64
# fuel_cost_per_unit_delivered    29523 non-null float64
# fuel_cost_per_mmbtu             29523 non-null float64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 2.5+ MB

# %%
fuel_df.skew(axis=0, skipna=True)
# Out:
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %%
fuel_df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_df.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
fuel_df[['fuel_unit']] = fuel_df[['fuel_unit']].fillna(value='mcf')

# %%
fuel_df.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
# group by the fuel type code year and print the first entries in all the groups formed
fuel_df.groupby('fuel_type_code_pudl').first()
# Out:
#                                   record_id  utility_id_ferc1  report_year  \
# fuel_type_code_pudl
# coal                  f1_fuel_1994_12_1_0_7                 1         1994
# gas                  f1_fuel_1994_12_2_0_10                 2         1994
# nuclear               f1_fuel_1994_12_2_1_1                 2         1994
# oil                   f1_fuel_1994_12_6_0_2                 6         1994
# other                f1_fuel_1994_12_11_0_6                11         1994
# waste                 f1_fuel_1994_12_9_0_3                 9         1994
#
#                      plant_name_ferc1 fuel_unit  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                         rockport       ton          5377489
# gas                         chickasaw       mcf            40533
# nuclear              joseph m. farley       kgU             2260
# oil                      clinch river       bbl             6510
# other                      w.f. wyman       bbl            55652
# ...

# %%
#checking for duplicates
fuel_df.duplicated().any()
# Out:
# False

# %%
fuel_df.head(10)
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
# 5  f1_fuel_1994_12_2_0_13                 2         1994
# 6   f1_fuel_1994_12_2_1_1                 2         1994
# 7  f1_fuel_1994_12_2_1_10                 2         1994
# 8  f1_fuel_1994_12_2_2_10                 2         1994
# 9   f1_fuel_1994_12_4_0_1                 4         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton          5377489
# 1  rockport total plant                coal       ton         10486945
# 2                gorgas                coal       ton          2978683
# ...

# %%
A = [1,2,3,4,5,6]

# %%
B = [13,21,34]

# %%
A.extend(B)

# %%
print(A)
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %%
import numpy as np

# %%
N = np.identity(3)

# %%
print(N)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
